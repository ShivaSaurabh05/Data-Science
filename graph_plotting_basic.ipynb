# %% [markdown]
# Created by Shiva Saurabh

# %% [markdown]
# Studied through "CampusX" on youtube!!

# %%
import pandas as pd
import numpy as np

# %%
bollywood = pd.read_csv("bollywood.csv",index_col="movie",squeeze=True)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_10396\4018275762.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   bollywood = pd.read_csv("bollywood.csv",index_col="movie",squeeze=True)

# %%
virat_kohli_runs = pd.read_csv("kohli_ipl.csv",index_col="match_no",squeeze=True)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_10396\3039800314.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   virat_kohli_runs = pd.read_csv("kohli_ipl.csv",index_col="match_no",squeeze=True)

# %%
subscriber = pd.read_csv("subs.csv",squeeze=True)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_10396\699450517.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   subscriber = pd.read_csv("subs.csv",squeeze=True)

# %%
subscriber.plot()
# Out:
# <AxesSubplot: >

# %%
num_movies = bollywood.value_counts()
top_actor = num_movies.head(20)
top_actor
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# John Abraham        18
# Saif Ali Khan       18
# Shahid Kapoor       17
# Sunny Deol          17
# Jimmy Sheirgill     16
# Tusshar Kapoor      16
# Irrfan Khan         14
# Arjun Rampal        14
# Manoj Bajpayee      14
# Anupam Kher         13
# Naseeruddin Shah    12
# Kangana Ranaut      12
# Hrithik Roshan      12
# Name: lead, dtype: int64

# %%
top_actor.plot(kind="bar")
# Out:
# <AxesSubplot: >
